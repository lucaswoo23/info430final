# %%
# Import libraries you would like to use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests 
from bs4 import BeautifulSoup as bs, SoupStrainer as ss
import re
import random

# %%
data = pd.read_csv('course_eval.csv')

# %%
would_take_again = []
for x in range(len(data)):
    would_take_again_data = random.uniform(0, 100)
    would_take_again_data = round(would_take_again_data, 2)
    would_take_again_data = would_take_again_data
    would_take_again.append(would_take_again_data)

# %%
data.insert(8, 'would_take_again', would_take_again)
# Out:
#                              course_name_number          instructor  \
# 0                     Arts & Sciences A A 198 A     Christopher Lum
# 1          Aeronautics & Astronautics A A 210 A         Daniel Cook
# 2          Aeronautics & Astronautics A A 210 A        Royan Dmello
# 3          Aeronautics & Astronautics A A 210 A        Royan Dmello
# 4          Aeronautics & Astronautics A A 210 A         Dana Dabiri
# 5          Aeronautics & Astronautics A A 260 A         Daniel Cook
# 6          Aeronautics & Astronautics A A 260 A      Eleanor Forbes
# 7          Aeronautics & Astronautics A A 301 A         Dana Dabiri
# 8          Aeronautics & Astronautics A A 302 A         Dana Dabiri
# 9          Aeronautics & Astronautics A A 310 A      Mehran Mesbahi
# 10         Aeronautics & Astronautics A A 311 A   Antonino Ferrante
# 11         Aeronautics & Astronautics A A 311 A   Antonino Ferrante
# 12         Aeronautics & Astronautics A A 312 A     Behcet Acikmese
# 13         Aeronautics & Astronautics A A 320 A       Owen Williams
# 14         Aeronautics & Astronautics A A 321 A     James Hermanson
# 15         Aeronautics & Astronautics A A 322 A     James Hermanson
# 16         Aeronautics & Astronautics A A 331 A         Jinkyu Yang
# 17         Aeronautics & Astronautics A A 332 A         Jinkyu Yang
# 18         Aeronautics & Astronautics A A 360 A    Mitsuru Kurosaka
# 19         Aeronautics & Astronautics A A 395 A        Susan Murphy
# 20         Aeronautics & Astronautics A A 402 A   Antonino Ferrante
# 21         Aeronautics & Astronautics A A 405 A      Anton Stepanov
# 22        Aeronautics & Astronautics A A 411 AC        Susan Murphy
# 23        Aeronautics & Astronautics A A 411 AG      Marco Salviato
# 24         Aeronautics & Astronautics A A 419 A  Robert Breidenthal
# 25         Aeronautics & Astronautics A A 440 A     Christopher Lum
# 26         Aeronautics & Astronautics A A 447 A     Behcet Acikmese
# 27         Aeronautics & Astronautics A A 448 A     Christopher Lum
# 28         Aeronautics & Astronautics A A 461 A    Mitsuru Kurosaka
# 29         Aeronautics & Astronautics A A 462 A       Adam Bruckner
# ...                                         ...                 ...
# 13640                   Philosophy VALUES 512 A    Stephen Gardiner
# 13641  Asian Language and Literature VIET 111 A    Bich-Ngoc Turner
# 13642  Asian Language and Literature VIET 112 A    Bich-Ngoc Turner
# 13643  Asian Language and Literature VIET 113 A    Bich-Ngoc Turner
# 13644  Asian Language and Literature VIET 211 A    Bich-Ngoc Turner
# 13645  Asian Language and Literature VIET 212 A    Bich-Ngoc Turner
# 13646  Asian Language and Literature VIET 213 A    Bich-Ngoc Turner
# 13647  Asian Language and Literature VIET 311 A    Bich-Ngoc Turner
# 13648  Asian Language and Literature VIET 312 A    Bich-Ngoc Turner
# 13649  Asian Language and Literature VIET 313 A    Bich-Ngoc Turner
# 13650                        Business WEL 300 A     Christy Johnson
# 13651                        Business WEL 400 A     Christy Johnson
# 13652             Arts & Sciences WETLAND 100 A     Diane Hennessey
# 13653             Arts & Sciences WETLAND 120 A       Paul Anderson
# 13654             Arts & Sciences WETLAND 125 A      Joseph Brentin
# 13655             Arts & Sciences WETLAND 125 A        William Hood
# 13656             Arts & Sciences WETLAND 130 A        Shelby Petro
# 13657             Arts & Sciences WETLAND 130 A     Douglas Gresham
# 13658             Arts & Sciences WETLAND 135 A    Suzanne Anderson
# 13659                 Arts & Sciences WRI 100 A      Scott Driscoll
# 13660             Arts & Sciences WRI CHI 100 A        Jolie Stekly
# 13661             Arts & Sciences WRI FIC 101 A      Scott Driscoll
# 13662             Arts & Sciences WRI FIC 102 A      Scott Driscoll
# 13663             Arts & Sciences WRI FIC 103 A      Scott Driscoll
# 13664             Arts & Sciences WRI MEM 101 A         Theo Nestor
# 13665             Arts & Sciences WRI MEM 102 A         Theo Nestor
# 13666             Arts & Sciences WRI MEM 103 A         Theo Nestor
# 13667             Arts & Sciences WRI SCR 101 A    Warren Etheredge
# 13668             Arts & Sciences WRI SCR 102 A    Warren Etheredge
# 13669             Arts & Sciences WRI SCR 103 A    Warren Etheredge
#
#        overall_ratings  content_ratings  contribution_ratings  \
# 0                 4.43             4.06                  4.43
# 1                 3.50             4.17                  3.17
# 2                 3.68             3.94                  3.96
# 3                 4.09             4.15                  4.31
# 4                 2.75             3.32                  2.80
# 5                 3.75             4.17                  4.00
# 6                 4.11             4.06                  4.69
# 7                 3.50             3.68                  3.17
# 8                 2.54             3.00                  2.64
# 9                 4.83             4.76                  4.89
# 10                5.00             5.00                  5.00
# 11                3.06             3.63                  3.09
# 12                3.58             3.65                  3.79
# 13                2.27             2.73                  2.56
# 14                3.39             3.75                  3.90
# 15                3.64             3.63                  3.83
# 16                4.62             4.73                  4.88
# 17                4.45             4.53                  4.80
# 18                2.77             3.14                  2.77
# 19                3.05             2.83                  3.08
# 20                3.81             3.95                  3.92
# 21                3.96             3.80                  4.23
# 22                3.00             3.00                  3.00
# 23                 NaN              NaN                   NaN
# 24                2.08             2.00                  1.43
# 25                4.18             4.08                  4.59
# 26                4.02             4.08                  4.18
# 27                4.20             4.25                  4.56
# 28                4.10             4.10                  4.50
# 29                4.09             4.27                  4.54
# ...                ...              ...                   ...
# 13640             4.17             4.25                  4.90
# 13641             4.50             4.50                  4.73
# 13642             4.75             4.64                  4.83
# 13643             4.57             4.78                  4.78
# 13644             4.80             4.80                  5.00
# 13645             4.17             4.17                  4.17
# 13646             4.17             4.50                  4.83
# 13647             4.00             4.17                  4.50
# 13648             4.50             4.50                  4.50
# 13649             4.75             4.25                  5.00
# 13650             3.71             3.60                  4.00
# 13651             4.57             4.57                  4.78
# 13652             4.19             4.30                  4.57
# 13653             3.28             3.50                  4.00
# 13654             3.93             3.83                  4.38
# 13655             3.50             4.00                  3.70
# 13656             4.00             3.88                  4.25
# 13657             3.17             3.17                  3.38
# 13658             3.88             3.80                  4.00
# 13659             4.38             4.08                  4.81
# 13660             4.93             4.83                  4.93
# 13661             4.64             4.75                  4.90
# 13662             4.36             4.33                  4.72
# 13663             4.75             4.75                  4.86
# 13664             4.89             4.89                  4.89
# 13665             4.90             4.97                  4.97
# 13666             4.38             4.38                  4.57
# 13667             4.86             4.60                  4.94
# 13668             4.88             4.88                  4.93
# 13669             4.81             4.81                  4.95
#
#        effectiveness_ratings  interest_ratings  amount_learned_ratings  \
# 0                       4.22              3.95                    3.86
# 1                       3.17              3.50                    3.83
# 2                       3.68              4.26                    4.08
# 3                       4.19              4.40                    4.41
# 4                       2.71              3.75                    3.06
# 5                       4.00              3.17                    4.00
# 6                       4.37              4.62                    4.07
# 7                       3.21              4.17                    3.50
# 8                       1.71              3.23                    2.33
# 9                       4.85              4.86                    4.83
# 10                      5.00              5.00                    5.00
# 11                      2.86              3.13                    3.43
# 12                      3.47              3.91                    3.93
# 13                      2.69              2.88                    2.73
# 14                      3.75              4.00                    3.58
# 15                      3.72              4.21                    3.79
# 16                      4.89              4.82                    4.50
# 17                      4.73              4.82                    4.50
# 18                      2.23              3.21                    2.38
# 19                      3.05              3.32                    3.13
# 20                      3.58              4.00                    3.71
# 21                      3.90              4.30                    4.13
# 22                      3.00              3.00                    3.00
# 23                       NaN               NaN                     NaN
# 24                      1.29              2.00                    2.00
# 25                      4.59              4.73                    4.11
# 26                      4.02              4.38                    4.22
# 27                      4.38              4.40                    4.56
# 28                      4.50              4.67                    4.25
# 29                      4.25              4.25                    4.00
# ...                      ...               ...                     ...
# 13640                   4.75              4.75                    4.00
# 13641                   4.59              4.50                    4.73
# 13642                   4.75              4.50                    4.64
# 13643                   4.57              4.38                    4.43
# 13644                   4.92              4.92                    5.00
# 13645                   4.17              4.83                    4.70
# 13646                   4.50              4.50                    4.50
# 13647                   4.17              4.90                    4.75
# 13648                   4.50              5.00                    5.00
# 13649                   5.00              4.75                    4.75
# 13650                   3.91              4.92                    3.92
# 13651                   4.57              4.78                    4.38
# 13652                   3.96              4.20                    4.41
# 13653                   3.13              4.62                    3.50
# 13654                   4.33              4.75                    3.25
# 13655                   3.70              2.93                    3.30
# 13656                   4.00              4.75                    3.88
# 13657                   2.93              3.07                    3.00
# 13658                   4.14              3.83                    3.88
# 13659                   4.42              4.20                    4.08
# 13660                   4.97              4.82                    4.77
# 13661                   4.75              4.83                    4.83
# 13662                   4.63              4.50                    4.36
# 13663                   4.75              4.93                    4.86
# 13664                   4.89              4.81                    4.81
# 13665                   4.90              4.86                    4.90
# 13666                   4.78              4.69                    4.38
# 13667                   4.75              5.00                    4.86
# 13668                   4.93              4.97                    4.83
# 13669                   4.89              4.89                    4.89
#
#       would_take_again  grading_ratings
# 0               79.62%             2.92
# 1               22.49%             3.50
# 2               20.51%             3.68
# 3               96.36%             4.23
# 4               77.49%             3.36
# 5                1.71%             4.17
# 6               54.71%             3.97
# 7               18.14%             3.30
# 8               27.14%             3.11
# 9               55.64%             4.26
# 10              90.27%             5.00
# 11              58.67%             3.27
# 12              31.94%             3.97
# 13              89.77%             1.55
# 14              90.59%             2.50
# 15              27.19%             3.94
# 16              89.57%             4.50
# 17               31.9%             4.30
# 18              34.35%             2.40
# 19              95.94%             3.35
# 20              34.15%             3.78
# 21              97.43%             3.80
# 22                3.9%             3.00
# 23              37.05%              NaN
# 24               5.79%             2.14
# 25              27.75%             4.00
# 26              50.95%             4.02
# 27              20.02%             2.80
# 28               4.48%             4.50
# 29              84.88%             3.78
# ...                ...              ...
# 13640           61.85%             4.50
# 13641             0.5%             4.73
# 13642           23.46%             4.90
# 13643            13.2%             4.78
# 13644           58.24%             5.00
# 13645           69.72%             4.93
# 13646           24.84%             4.83
# 13647           32.72%             4.00
# 13648           85.21%             4.00
# 13649           73.48%             4.75
# 13650            7.24%             4.14
# 13651           72.47%             4.25
# 13652           65.42%             3.33
# 13653            60.3%             3.17
# 13654           56.62%             3.58
# 13655           40.41%             2.80
# 13656           79.73%             4.25
# 13657           92.72%             3.18
# 13658             4.7%             3.83
# 13659           73.57%             3.63
# 13660           77.64%             0.00
# 13661           64.79%             4.36
# 13662           24.89%             4.25
# 13663           74.68%             4.83
# 13664            32.3%             4.67
# 13665           60.98%             4.82
# 13666            51.3%             4.57
# 13667            2.41%             4.83
# 13668           86.28%             4.69
# 13669           60.26%             4.67
#
# [13670 rows x 10 columns]

# %%
all_countries = []
for x in range(10000):
    all_countries.append('United States')

# %%
potential_countries = ['China', 'Japan', 'India', 'Canada']
for x in range(len(data) - 10000):
    index = random.randint(0, len(potential_countries))
    all_countries.append(potential_countries[index - 1])

# %%
data.insert(10, 'user_country', all_countries)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-ec53fa36163e> in <module>
# ----> 1 data.insert(10, 'user_country', all_countries)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3218         """
#    3219         self._ensure_valid_index(value)
# -> 3220         value = self._sanitize_column(column, value, broadcast=False)
#    3221         self._data.insert(loc, column, value,
#    3222                           allow_duplicates=allow_duplicates)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
#    3392             if not isinstance(value, (np.ndarray, Index)):
#    3393                 if isinstance(value, list) and len(value) > 0:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _sanitize_index(data, index, copy)
#    3999
#    4000     if len(data) != len(index):
# -> 4001         raise ValueError('Length of values does not match length of ' 'index')
#    4002
#    4003     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
all_cities = []
potential_cities = ['Los Angeles', 'Portland', 'San Francisco', 'Bellevue', 'Issaquah', "Seattle", 'Boston']
for x in range(10000):
    index = random.randint(0, len(potential_cities))
    all_cities.append(potential_cities[index - 1])

# %%
potential_cities = ['Toronto', 'Shanghai', 'Vancouver', 'Osaka', 'Tokyo', 'Mumbai']
for x in range(len(data) - 10000):
    index = random.randint(0, len(potential_cities))
    all_cities.append(potential_cities[index - 1])

# %%
data.insert(11, 'user_city', all_cities)

# %%
is_recorded = [];
is_recorded_options = ['yes', 'no']
for x in range(len(data)):
    index = random.randint(0, len(is_recorded_options))
    is_recorded.append(is_recorded_options[index - 1])

# %%
data.insert(12, 'is_recorded', is_recorded)

# %%
teaching_style = [];
teaching_style_options = ['visual', 'powerpoint driven', 'problem based', 'online', 'alternative resource heavy', 'industry example based', 'group work focused']
for x in range(len(data)):
    index = random.randint(0, len(teaching_style_options))
    teaching_style.append(teaching_style_options[index - 1])

# %%
data.insert(12, 'teaching_style', teaching_style)

# %%
participation_weight = []
for x in range(len(data)):
    participation_weight_data = random.uniform(0, 5)
    participation_weight_data = round(participation_weight_data, 2)
    participation_weight.append(participation_weight_data)

# %%
data.insert(13, 'participation_weight', participation_weight)

# %%
level_of_group_work = []
for x in range(len(data)):
    level_of_group_work_data = random.uniform(0, 5)
    level_of_group_work_data = round(level_of_group_work_data, 2)
    level_of_group_work.append(level_of_group_work_data)

# %%
data.insert(14, 'level_of_group_work', level_of_group_work)

# %%
exam_weight = []
for x in range(len(data)):
    exam_weight_data = random.uniform(0, 5)
    exam_weight_data = round(exam_weight_data, 2)
    exam_weight.append(exam_weight_data)

# %%
data.insert(15, 'exam_weight', exam_weight)

# %%
exam_difficulty = []
for x in range(len(data)):
    exam_difficulty_data = random.uniform(0, 5)
    exam_difficulty_data = round(exam_difficulty_data, 2)
    exam_difficulty.append(exam_difficulty_data)

# %%
data.insert(16, 'exam_difficulty', exam_difficulty)

# %%
homework_amount = []
for x in range(len(data)):
    homework_amount_data = random.uniform(0, 5)
    homework_amount_data = round(homework_amount_data, 2)
    homework_amount.append(homework_amount_data)

# %%
data.insert(17, 'homework_amount', homework_amount)
